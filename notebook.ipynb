# %%
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib as plt

# %%
image = Image.open('lina.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=884x1080 at 0x1EA4E49D788>

# %%
r, g, b = image.split()

# %%
cropped = image.crop((0, 80, 200, 400))
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=200x320 at 0x1EA4E79B388>

# %%
blurred = image.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)
blurred = blurred.filter(ImageFilter.SHARPEN)

blurred
# Out:
# <PIL.Image.Image image mode=RGB size=884x1080 at 0x1EA4E6FFA48>

# %%
enhancer = ImageEnhance.Brightness(image)
a = []
for i in range(10):
    factor = i / 10.0
    a.append(enhancer.enhance(factor))

# %%
a[5]
# Out:
# <PIL.Image.Image image mode=RGB size=884x1080 at 0x1EA4E7928C8>

# %%
image.getpixel((0,0))
# Out:
# (143, 92, 61)
